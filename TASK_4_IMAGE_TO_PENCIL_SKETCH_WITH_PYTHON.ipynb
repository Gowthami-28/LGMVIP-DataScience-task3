# %% [markdown]
# <a href="https://colab.research.google.com/github/Gowthami-28/LGMVIP-DataScience-task3/blob/main/TASK_4_IMAGE_TO_PENCIL_SKETCH_WITH_PYTHON.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **IMAGE TO PENCIL SKETCH WITH PYTHON
# Beginner Level-Task4**

# %%
from google.colab.patches import cv2_imshow
import cv2
#read the image
img=cv2.imread('/content/girl.jpg')

# %%
#converting image into gray scale image
img_gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=612x395 at 0x7FB619813D50>

# %%
#inverting the image
img_invert = cv2.bitwise_not(img_gray)

cv2_imshow(img_invert)
# Out:
# <PIL.Image.Image image mode=L size=612x395 at 0x7FB60CB18750>

# %%
#Smoothing of the image
img_smoothing = cv2.GaussianBlur(img_invert, (21, 21),sigmaX=0, sigmaY=0)

cv2_imshow(img_smoothing)
# Out:
# <PIL.Image.Image image mode=L size=612x395 at 0x7FB60CB18390>

# %%
#Obtaining the final sketch
def dodgeV2(x, y):
 return cv2.divide(x, 255 - y, scale=256)

# %%
#final output as sketch
final_img = dodgeV2(img_gray, img_smoothing)

cv2_imshow(final_img)
# Out:
# <PIL.Image.Image image mode=L size=612x395 at 0x7FB60CB18A50>
